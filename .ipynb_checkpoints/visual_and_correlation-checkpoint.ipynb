# %%
# Created 7/6/21
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import norm, chisquare, chi2, linregress, chi2_contingency
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DATA/avgsV1/avgs2013-14.csv', index_col=0)
df = df[df['NEXT_GAME_ID'] != 0]

# %%
x = df['E_NET_RATING']
y = df['NEXT_PLUS_MINUS']

fig = plt.figure(figsize=(10,10))
plt.scatter(x, y)

slope, intercept, rval, pval, stderr = linregress(x, y)
plt.plot(x, intercept+slope*x, label="Best fit")
# plt.xticks(np.arange(10))
plt.legend()
plt.show()

# %%
print(f"slope = {slope}\nIntercept = {intercept}\nR = {rval}\nr^2 = {rval**2}\np_val={pval}")
# Out:
# slope = 0.633674820219458
# Intercept = -0.20552337403380033
# R = 0.2628938695192452
# r^2 = 0.06911318663080192
# p_val=1.7560967419955307e-42

# %%
dl = ['PTS', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
       'BLK', 'TOV', 'PF', 'E_OFF_RATING',
       'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING', 'E_NET_RATING',
       'NET_RATING', 'AST_PCT', 'AST_TOV', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT',
       'REB_PCT', 'E_TM_TOV_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'USG_PCT',
       'E_USG_PCT', 'E_PACE', 'PACE', 'PACE_PER40', 'POSS', 'PIE', 'FTA_RATE',
       'OPP_EFG_PCT', 'OPP_FTA_RATE', 'OPP_TOV_PCT', 'OPP_OREB_PCT',
       'PTS_OFF_TOV', 'PTS_2ND_CHANCE', 'PTS_FB', 'PTS_PAINT',
       'OPP_PTS_OFF_TOV', 'OPP_PTS_2ND_CHANCE', 'OPP_PTS_FB', 'OPP_PTS_PAINT',
       'BLKA', 'PFD', 'PCT_FGA_2PT', 'PCT_FGA_3PT', 'PCT_PTS_2PT',
       'PCT_PTS_2PT_MR', 'PCT_PTS_3PT', 'PCT_PTS_FB', 'PCT_PTS_FT',
       'PCT_PTS_OFF_TOV', 'PCT_PTS_PAINT', 'PCT_AST_2PM', 'PCT_UAST_2PM',
       'PCT_AST_3PM', 'PCT_UAST_3PM', 'PCT_AST_FGM', 'PCT_UAST_FGM']

# %%
res_d = {}
mrval = 0
for i in dl:
    tx = df[i]
    slope, intercept, rval, pval, stderr = linregress(tx, y)
    res_d[i] = rval
    if rval > mrval:
        mind = i
        mrval = rval
mind
# Out:
# C:\Users\Dylan\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\Dylan\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\Dylan\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Users\Dylan\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# C:\Users\Dylan\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:128: RuntimeWarning: divide by zero encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# 'E_NET_RATING'

# %%
# Out:
# {'PTS': 0.15754676287180833,
#  'FGM': 0.11320466809899157,
#  'FGA': -0.08351470168388728,
#  'FG_PCT': 0.18044597664536405,
#  'FG3M': 0.09852027623448165,
#  'FG3A': 0.06607827647394238,
#  'FG3_PCT': 0.11757683287970881,
#  'FTM': 0.10021023251421,
#  'FTA': 0.07147524510914824,
#  'FT_PCT': 0.06389681185614117,
#  'OREB': -0.08616556499249908,
#  'DREB': 0.09357528542269071,
#  'REB': 0.01523583376737803,
#  'AST': 0.11674533316650247,
#  'STL': 0.016375744554023373,
#  'BLK': 0.03455187653703492,
#  'TOV': -0.056124686986313545,
#  'PF': -0.06934502710951707,
#  'E_OFF_RATING': 0.21375239005139968,
#  'OFF_RATING': 0.21198290189433724,
#  'E_DEF_RATING': -0.15483293911866197,
#  'DEF_RATING': -0.15504242119034078,
#  'E_NET_RATING': 0.2628938695192452,
#  'NET_RATING': 0.2625293510569152,
#  'AST_PCT': 0.07578443250531434,
#  'AST_TOV': 0.1129213494644689,
#  'AST_RATIO': 0.13643808553178502,
#  'OREB_PCT': nan,
#  'DREB_PCT': nan,
#  'REB_PCT': nan,
#  'E_TM_TOV_PCT': -0.04948241732129788,
#  'TM_TOV_PCT': -0.05997801233272506,
#  'EFG_PCT': 0.1824997398844636,
#  'TS_PCT': 0.20233638379286661,
#  'USG_PCT': 0.0,
#  'E_USG_PCT': 0.005886878802841622,
#  'E_PACE': -0.0015648854407557897,
#  'PACE': 0.006253566727326834,
#  'PACE_PER40': 0.0062474957291114375,
#  'POSS': -0.00626359846764709,
#  'PIE': 0.2597267848338169,
#  'FTA_RATE': 0.09259067425955234,
#  'OPP_EFG_PCT': -0.11182774633725438,
#  'OPP_FTA_RATE': -0.07413832292495778,
#  'OPP_TOV_PCT': 0.02752727787625001,
#  'OPP_OREB_PCT': -0.08998572855525108,
#  'PTS_OFF_TOV': 0.07799704609895686,
#  'PTS_2ND_CHANCE': -0.054636356852128795,
#  'PTS_FB': 0.02324783650204559,
#  'PTS_PAINT': 0.010458193496542928,
#  'OPP_PTS_OFF_TOV': -0.07365110530105505,
#  'OPP_PTS_2ND_CHANCE': -0.019909901962429113,
#  'OPP_PTS_FB': -0.13236486433131442,
#  'OPP_PTS_PAINT': -0.052033176546340265,
#  'BLKA': -0.1497353177879532,
#  'PFD': 0.09403001126359868,
#  'PCT_FGA_2PT': -0.08910435897943711,
#  'PCT_FGA_3PT': 0.08903751877908211,
#  'PCT_PTS_2PT': -0.09368094492201247,
#  'PCT_PTS_2PT_MR': -0.0177638076633106,
#  'PCT_PTS_3PT': 0.06641786558229633,
#  'PCT_PTS_FB': -0.015027355519626827,
#  'PCT_PTS_FT': 0.046132805437501076,
#  'PCT_PTS_OFF_TOV': 0.011700507690438454,
#  'PCT_PTS_PAINT': -0.06490460595955344,
#  'PCT_AST_2PM': 0.055475277058824185,
#  'PCT_UAST_2PM': -0.05544423056284822,
#  'PCT_AST_3PM': 0.024534140136011368,
#  'PCT_UAST_3PM': -0.026253561554118846,
#  'PCT_AST_FGM': 0.07578443250531434,
#  'PCT_UAST_FGM': -0.07579843188281274}
